# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 2.0. Coupler Design

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# ### 0.1. General libraries

# %% [markdown]
# **Run only the first time you execute this Jupyter Notebook**
# You can delete this command lines after succesfully installing this tools

# %%
#!sudo apt-get install libgomp1
#!sudo apt-get install libxft2
#!sudo apt-get install libglu1

# %% [markdown]
# Run everytime you start to execute this Jupyter Notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

import tidy3d as td
import gplugins.tidy3d as gt

nm = 1e-3
wavelength = np.linspace(1500, 1600) * nm
f = td.C_0 / wavelength

# %% [markdown]
# ### 0.2. Functions by us

# %%
from upvfab_design_tools import MMI_EME, DC_EME

# %% [markdown]
# ## LO.1. Directional coupler cross-section in GDSFactory
#
# ### 1.1. Materials

# %%
nitride_complex = td.material_library["Si3N4"]["Luke2015PMLStable"].eps_model(f)
nitride_index, nitride_k = td.Medium.eps_complex_to_nk(nitride_complex)
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)

# %% [markdown]
# ### 1.2. Cross-Section Definition
#
# In GDSFactory - Tidy3d modesolver we have another function to easily define the Cross-Section of a Directional Coupler: [gt.modes.WaveguideCoupler()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.WaveguideCoupler.html). It implements the deep (rib) and shallow (ridge) directional coupler waveguides cross-section, using as input parameters all the dimensions of the waveguide cores and also the distance between them (gap).

# %%
lambda_c = 1.55

dcoupler_cs = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1.2, 1.2), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=600 * nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

dcoupler_cs.plot_index()

# %% [markdown]
# ### 1.3. Simulations
#
# #### 1.3.1. Parameters
#
# As before, we can calculate the effective index (n_eff), TE and TM fraction for this cross-section using the already implemented class methods: .n_eff, .fraction_te and .fraction_tm. Remember that we will calculate one effective index for each mode (up to num_modes)

# %%
dcoupler_neff = dcoupler_cs.n_eff
print(dcoupler_neff)
# Out:
# 2026-05-02 10:05:04.217 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbc1bb971a882eda.npz.
# [1.60942484+1.02849974e-04j 1.60116589+9.83178135e-05j
#  1.53540293+1.77367472e-04j 1.52057329+1.77190584e-04j]

# %%
dcoupler_cs.fraction_te
# Out:
# array([0.994898  , 0.99527537, 0.00888064, 0.01130183])

# %%
dcoupler_cs.fraction_tm
# Out:
# array([0.005102  , 0.00472463, 0.99111936, 0.98869817])

# %% [markdown]
# #### 1.3.2. Plots
#
# We could also plot the fields for each mode identified. Remember: the 'Ex' field component corresponds to TE modes, while the 'Ey' field component corresponds to TM modes. In the case of the directional coupler, the even and odd modes play a key role in facilitating energy exchange between the waveguides. Now, let's plot and analyze their behavior.

# %%
dcoupler_cs.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)
) #

# %%
dcoupler_cs.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
dcoupler_cs.plot_field(mode_index=2 , # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
dcoupler_cs.plot_field(mode_index=3, # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# #### 1.3.3. Beating or Coupling Length calculation (𝐿𝜋)
#
# The key parameter that determines the design of a directional coupler is the coupling or beating length. This length defines the total size of the coupling region required to transfer all the optical power from one waveguide to another. It is determined by the difference between the effective indices of the cross-section's odd and even modes:

# %%
# TE Modes: Modes 0 & 1
L_pi_TE = 0.5*lambda_c/(dcoupler_neff[0].real-dcoupler_neff[1].real)
print(L_pi_TE)

L_pi_TM =  0.5*lambda_c/(dcoupler_neff[2].real-dcoupler_neff[3].real)
print(L_pi_TM)
# Out:
# 93.83767536700753
# 52.26022367744142

# %% [markdown]
# GDSFactory has its own method implemented to calculate the coupling length: [.coupling_length()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.WaveguideCoupler.html)

# %%
dcoupler_cs.coupling_length() #da Lpi-> a veces da bien, otras veces no es tan precisa. Vale cuando no tenemos que hacer un barrido de lambda
# Out:
# array([93.83767537, 52.26022368])

# %% [markdown]
# ## LO.2. Directional coupler length and coupling coefficient
#
# The total power transferred to the output is modeled using the coupling coefficient (K). This coefficient depends on the relationship between the physical length of the coupling region and the beating length:
#
# <img src="k.png" alt="Coupling Coefficient Equation" width="400">
#
# Simulate a directional coupler that implements two deep waveguide cores of thickness 300 nm, 1.2 microns width and with a gap of 600 nm between them.
# - Plot the transfer function: K vs L/Lpi
# - Comment the results: distance needed for a complete energy transfer between waveguides, distance needed for splitting power in half..

# %%
L_Lpi = np.linspace(0,4,100)
K = np.sin(0.5*np.pi*(L_Lpi))**2

plt.plot(L_Lpi,K)
plt.xlabel("L/L_pi")
plt.ylabel("K")
plt.grid()

# %% [markdown]
# ## LO.3. 2x2 Directional Coupler
#
# Here, you will use some functions provided by us (check **0. Imports** for more details) to simulate the propagation in a 2x2 (50/50) directional coupler. Please read all the comments in the following code carefully and **make changes only to the lines marked with the #Student tag**

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 1.2 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/alexia/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  580.4293623071611  µm
# /home/alexia/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change any geometrical parameter
# (waveguide widths or gap) you can skip last cell. 
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/5804 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 290.2147
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.8916
# Total OUT power: 0.8818
# Excess loss [dB] =  0.5464
# ------------------------
# Power over OUTs:  ['0.4407', '0.4410']
# Ratio over OUTs ['0.4998', '0.5002']

# %% [markdown]
# Now sweep gaps between 0.2 and 1.2 µm in steps of 0.2 µm

# %% [markdown]
# ## LO.4. Parallel uncoupled waveguides
#
# Parallel waveguides always exhibit some evanescent coupling. In this exercise, the goal is to control coupling so that adjacent waveguides remain effectively uncoupled. Define an uncoupled pair as one with coupling coefficient K < 0.01. Assume a parallel interaction length of L = 10 mm (typical chip length). For both shallow-etched and deep-etched waveguides, compute the minimum waveguide gap that satisfies this condition for the **TE0** mode, using w = 1.0 um and lambda = 1.55 um.

# %%
# HINT. Calculate manually the L_pi you may need to achieve K=0.01
# Then you can sweep the gap and calculate the L_pi until reaching 
# the desired value. 

L = 10 # 10mm
K = 0.01
L_pi = 0.5*np.pi*L/(np.arcsin(np.sqrt(K)))
print("L_pi para K= 0.01:", L_pi, "mm")
# Out:
# L_pi para K= 0.01: 156.81708768975523 mm

# %%
# DEEP WAVEGUIDE

lambda_c = 1.55
L = 10*10**3 # 10mm

dcoupler_cs = gt.modes.WaveguideCoupler(
        core_width=(1, 1),
        slab_thickness=0 * nm,
        core_thickness=300 * nm,
        gap=950*nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=lambda_c,
        num_modes=4,
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
)
L_pi = dcoupler_cs.coupling_length()
K = np.sin(0.5 * np.pi * (L / L_pi))**2

print(L_pi,K)
# Out:
# 2026-05-02 10:05:24.887 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4adae8ca005a4062.npz.
# [156.40402186  78.33326779] [0.00976898 0.25956199]

# %%
# DEEP WAVEGUIDE

lambda_c = 1.55
L = 10*10**3 # 10mm

gaps = np.arange(2.5, 5.5, 0.01)

L_pi_list = []
K_list = []

for g in gaps:
    dcoupler_cs = gt.modes.WaveguideCoupler(
        core_width=(1, 1),
        slab_thickness=0 * nm,
        core_thickness=300 * nm,
        gap=float(g),
        core_material='sin',
        clad_material='sio2',
        wavelength=lambda_c,
        num_modes=4,
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
    )

    L_pi = dcoupler_cs.coupling_length()
    K = np.sin(0.5 * np.pi * (L / L_pi[0]))**2

    L_pi_list.append(L_pi)
    K_list.append(K)
# Out:
# 2026-05-02 10:05:24.921 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_87641d4cdc9dd751.npz.
# 2026-05-02 10:05:24.929 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5a5d6ca32bb15118.npz.
# 2026-05-02 10:05:24.934 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_644a8f7c435fa31a.npz.
# 2026-05-02 10:05:24.939 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6f46d43a8f047b08.npz.
# 2026-05-02 10:05:24.943 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b8e99887a36e4b7d.npz.
# 2026-05-02 10:05:24.949 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f046a2e5845893e2.npz.
# 2026-05-02 10:05:24.953 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_215e567a3b0b8915.npz.
# 2026-05-02 10:05:24.957 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ec073310cbebbe33.npz.
# 2026-05-02 10:05:24.967 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f1830cfd5dcb33a3.npz.
# 2026-05-02 10:05:24.970 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_408f7168ca424d6d.npz.
# 2026-05-02 10:05:24.973 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ee0ce79988f8dd74.npz.
# 2026-05-02 10:05:24.976 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3703f981974ecfe3.npz.
# 2026-05-02 10:05:24.982 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_22643ef40e53330b.npz.
# 2026-05-02 10:05:24.987 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7223f772e1a5153b.npz.
# 2026-05-02 10:05:24.991 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_94958d4154002d1b.npz.
# 2026-05-02 10:05:24.996 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_79efd20e58a6f047.npz.
# 2026-05-02 10:05:24.999 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a4aa323f728fb758.npz.
# 2026-05-02 10:05:25.003 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_193b856a30e02633.npz.
# 2026-05-02 10:05:25.006 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9401f3def7b2fc14.npz.
# 2026-05-02 10:05:25.010 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a1e13f0c05114bba.npz.
# 2026-05-02 10:05:25.014 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c59981d33b60dec2.npz.
# 2026-05-02 10:05:25.018 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_687c8412164addf9.npz.
# 2026-05-02 10:05:25.022 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e781efa2d11809a8.npz.
# 2026-05-02 10:05:25.025 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d718eb9afb419260.npz.
# 2026-05-02 10:05:25.030 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6a772bc13148d683.npz.
# 2026-05-02 10:05:25.033 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f97c526579cea0c0.npz.
# 2026-05-02 10:05:25.038 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2a5f6fdecbc42095.npz.
# 2026-05-02 10:05:25.043 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_58061459ba1543f1.npz.
# 2026-05-02 10:05:25.047 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a6f19b247f02f180.npz.
# 2026-05-02 10:05:25.051 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7839baf3d9825d95.npz.
# 2026-05-02 10:05:25.055 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e5aca4d5bc5bbd8e.npz.
# 2026-05-02 10:05:25.061 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1d5122de9c115fd0.npz.
# 2026-05-02 10:05:25.066 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f523b677c9f4587c.npz.
# 2026-05-02 10:05:25.071 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ef16e53005956cde.npz.
# 2026-05-02 10:05:25.079 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler
| INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6d94c092519c7425.npz.
# 2026-05-02 10:05:26.719 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_83f0706f1aaaaa70.npz.
# 2026-05-02 10:05:26.723 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_30e97a5bfa9a4b0b.npz.
# 2026-05-02 10:05:26.728 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_95bfea286540a73f.npz.
# 2026-05-02 10:05:26.734 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_674c8a666316400b.npz.
# 2026-05-02 10:05:26.738 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_df84377c4c36aa87.npz.
# 2026-05-02 10:05:26.744 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f54924ce119067cc.npz.
# 2026-05-02 10:05:26.748 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ac930ee321e573fd.npz.
# 2026-05-02 10:05:26.755 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1661ae113edd1df6.npz.
# 2026-05-02 10:05:26.761 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8e369e77a5b42a60.npz.
# 2026-05-02 10:05:26.768 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a2f2bfcf92d06e35.npz.
# 2026-05-02 10:05:26.774 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7f6b4e9813d82125.npz.
# 2026-05-02 10:05:26.778 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e4764a501d33961a.npz.
# 2026-05-02 10:05:26.782 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9c37b2dbc79e7c56.npz.
# 2026-05-02 10:05:26.787 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9622e1b4cf7d03ee.npz.
# 2026-05-02 10:05:26.791 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_331349e8d8934adc.npz.
# 2026-05-02 10:05:26.795 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_204db69c79785608.npz.
# 2026-05-02 10:05:26.800 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_031dd1256142c22d.npz.
# 2026-05-02 10:05:26.804 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ffaa831f85f45a72.npz.
# 2026-05-02 10:05:26.808 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2fbc6ed58536bfc0.npz.
# 2026-05-02 10:05:26.813 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5e37a190112812da.npz.
# 2026-05-02 10:05:26.817 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f26914265b8d22b5.npz.
# 2026-05-02 10:05:26.821 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6dd517d86a828997.npz.
# 2026-05-02 10:05:26.826 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_446ea3acb7a5430f.npz.
# 2026-05-02 10:05:26.830 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f0f220f45d99e58a.npz.
# 2026-05-02 10:05:26.834 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f24ea6d2100f71af.npz.
# 2026-05-02 10:05:26.838 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bc1559dbcfc195a4.npz.
# 2026-05-02 10:05:26.842 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fdaec79a5038aac6.npz.
# 2026-05-02 10:05:26.846 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_43f14ec3f05a583b.npz.
# 2026-05-02 10:05:26.851 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_77743a026889e627.npz.
# 2026-05-02 10:05:26.855 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_aae15837a969e92f.npz.
# 2026-05-02 10:05:26.859 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6325924433d0319d.npz.
# 2026-05-02 10:05:26.865 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7002b989837ddae1.npz.
# 2026-05-02 10:05:26.870 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ae02ae14051f205c.npz.
# 2026-05-02 10:05:26.874 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a97fc52c04516824.npz.
# 2026-05-02 10:05:26.877 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_36430bdbb2ad2690.npz.
# 2026-05-02 10:05:26.885 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_89014e8431b53c2d.npz.
# 2026-05-02 10:05:26.889 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_477facb1bb5d6923.npz.
# 2026-05-02 10:05:26.893 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e0ea10b819c1ad7e.npz.
# 2026-05-02 10:05:26.898 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_473246e40c91ee47.npz.

# %%
plt.plot(gaps, K_list)
plt.axhline(y=0.01, color='r', linestyle='--', label='K = 0.01')
plt.legend()
plt.ylabel("K")
plt.xlabel("Gap(um)")
plt.show()

# %%
# SHALLOW WAVEGUIDE

lambda_c = 1.55
L = 10*10**3 # 10mm

gaps = np.arange(4, 7, 0.01)

L_pi_list = []
K_list = []

for g in gaps:
    dcoupler_cs = gt.modes.WaveguideCoupler(
        core_width=(1, 1),
        slab_thickness=150 * nm,
        core_thickness=300 * nm,
        gap=float(g),
        core_material='sin',
        clad_material='sio2',
        wavelength=lambda_c,
        num_modes=4,
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
    )

    L_pi = dcoupler_cs.coupling_length()
    K = np.sin(0.5 * np.pi * (L / L_pi[0]))**2

    L_pi_list.append(L_pi)
    K_list.append(K)
# Out:
# 2026-05-02 10:05:27.107 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6ad366802df01731.npz.
# 2026-05-02 10:05:27.115 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b3ab2006ddb8ed3c.npz.
# 2026-05-02 10:05:27.121 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e3ce015207df785a.npz.
# 2026-05-02 10:05:27.129 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9aaea43a34bf72b6.npz.
# 2026-05-02 10:05:27.133 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2ffd2fb2f6c2c408.npz.
# 2026-05-02 10:05:27.139 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3465c58f612de7f3.npz.
# 2026-05-02 10:05:27.145 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cf9f59add50e48a0.npz.
# 2026-05-02 10:05:27.150 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7112c25fe252c2e1.npz.
# 2026-05-02 10:05:27.155 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b725f505cf63ca43.npz.
# 2026-05-02 10:05:27.158 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5a5446dd6aa33c00.npz.
# 2026-05-02 10:05:27.164 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d1f454641b6c39a7.npz.
# 2026-05-02 10:05:27.168 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bbd6568969fdfb73.npz.
# 2026-05-02 10:05:27.172 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2001cf7dae29a20e.npz.
# 2026-05-02 10:05:27.178 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8af1ee08bbeceafc.npz.
# 2026-05-02 10:05:27.183 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0b17bf08df6e9717.npz.
# 2026-05-02 10:05:27.186 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9a392c72b5bbed71.npz.
# 2026-05-02 10:05:27.190 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_31481f92b3a2718a.npz.
# 2026-05-02 10:05:27.195 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fb52cb9753fab548.npz.
# 2026-05-02 10:05:27.200 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_02e3d65940bd3ccb.npz.
# 2026-05-02 10:05:27.204 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_55bd22bab5c77156.npz.
# 2026-05-02 10:05:27.209 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_16886b245c1c9498.npz.
# 2026-05-02 10:05:27.218 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b168be7897abd144.npz.
# 2026-05-02 10:05:27.222 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_265f869396791505.npz.
# 2026-05-02 10:05:27.228 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_00aedcf3f89ee509.npz.
# 2026-05-02 10:05:27.234 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3043520a7398f204.npz.
# 2026-05-02 10:05:27.243 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_52f07f690f80b1ec.npz.
# 2026-05-02 10:05:27.249 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_074232e94afc72cf.npz.
# 2026-05-02 10:05:27.253 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_365b86c3ae191a43.npz.
# 2026-05-02 10:05:27.261 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5969fd05f63f4932.npz.
# 2026-05-02 10:05:27.267 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_11a8dcb10b89896d.npz.
# 2026-05-02 10:05:27.271 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cf06f0c2b0b854aa.npz.
# 2026-05-02 10:05:27.279 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7c9aaf2a24472607.npz.
# 2026-05-02 10:05:27.282 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4cc35e20f12d8515.npz.
# 2026-05-02 10:05:27.286 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6da7b3d0187c9f34.npz.
# 2026-05-02 10:05:27.288 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a9705b0a590411fd.npz.
# 2026-05-02 10:05:27.292 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_72011372f908a160.npz.
# 2026-05-02 10:05:27.295 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b5bb66a37421cceb.npz.
# 2026-05-02 10:05:27.298 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fe2b4c25f871e298.npz.
# 2026-05-02 10:05:27.301 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler
| INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9f564822363a398b.npz.
# 2026-05-02 10:05:28.422 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fe2392e12d7a0f9c.npz.
# 2026-05-02 10:05:28.427 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_17a9fcf343408194.npz.
# 2026-05-02 10:05:28.430 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_16fe746a8e1e621d.npz.
# 2026-05-02 10:05:28.434 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_44130d58c3abb12a.npz.
# 2026-05-02 10:05:28.438 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0662dcfeecd9996a.npz.
# 2026-05-02 10:05:28.443 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_054349f390b690f0.npz.
# 2026-05-02 10:05:28.446 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0358685b8e0174b7.npz.
# 2026-05-02 10:05:28.449 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_acac9ea925b4b5a5.npz.
# 2026-05-02 10:05:28.454 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9573a411286e23f3.npz.
# 2026-05-02 10:05:28.459 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_718f3b1fbd2c5e00.npz.
# 2026-05-02 10:05:28.462 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_15aac09fe6406d29.npz.
# 2026-05-02 10:05:28.466 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8743d1c998ccd703.npz.
# 2026-05-02 10:05:28.469 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_81a76c99196f4ea9.npz.
# 2026-05-02 10:05:28.474 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fc76e9c3a2f9934f.npz.
# 2026-05-02 10:05:28.479 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a46b12643b04859d.npz.
# 2026-05-02 10:05:28.485 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2cca23ff79baa75b.npz.
# 2026-05-02 10:05:28.491 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cfdd5a64b0526be9.npz.
# 2026-05-02 10:05:28.497 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_acee2f4e454cdf27.npz.
# 2026-05-02 10:05:28.502 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a7e78eecb463ffdc.npz.
# 2026-05-02 10:05:28.507 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7b9391044ec28135.npz.
# 2026-05-02 10:05:28.511 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cb03d0f7eebe030b.npz.
# 2026-05-02 10:05:28.515 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4b09404a39b7f07d.npz.
# 2026-05-02 10:05:28.521 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_015458b65a3ca6b2.npz.
# 2026-05-02 10:05:28.525 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_69dcbe78a780bb8e.npz.
# 2026-05-02 10:05:28.528 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0d38c16821c95267.npz.
# 2026-05-02 10:05:28.531 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_008eaca56e93ad6c.npz.
# 2026-05-02 10:05:28.535 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_052f5ece484cb4f8.npz.
# 2026-05-02 10:05:28.540 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8b811b9745f5e975.npz.
# 2026-05-02 10:05:28.544 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_76f8fb5623c20e2f.npz.
# 2026-05-02 10:05:28.548 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_90a1329425e1813a.npz.
# 2026-05-02 10:05:28.551 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f2400f3b61a37830.npz.
# 2026-05-02 10:05:28.556 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0f5312bfecd96a45.npz.
# 2026-05-02 10:05:28.560 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_38a727df8f50e714.npz.
# 2026-05-02 10:05:28.564 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bede42cb09335e26.npz.
# 2026-05-02 10:05:28.567 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_af3704df9114a3f2.npz.

# %%
plt.plot(gaps, K_list)
plt.axhline(y=0.01, color='r', linestyle='--', label='K = 0.01')
plt.legend()
plt.ylabel("K")
plt.xlabel("Gap(um)")
plt.show()

# %% [markdown]
# ## LO.5. Multimode Interference (MMI) Coupler cross-section
#
# ### LO.5.1. Cross-Section definition and simulation
#
# In GDSFactory - Tidy3d modesolver, we can simulate the Cross-Section of a multimode interference coupler using the previously studied : [gt.modes.Waveguide()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.Waveguide.html) function. The parameters will correspond to the dimensions of the MMI body section.

# %%
mmi_body_w = 12  
lambda_c = 1550*nm

mmi_body_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=mmi_body_w, # MMI Body width
    core_thickness=300 * nm, # MMI Body height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=20, # Targeted number of modes to find - Higher than before! It's a multimode section
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

mmi_body_waveguide.n_eff
# Out:
# 2026-05-02 10:05:28.769 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6c30818797bb0c38.npz.
# array([1.6786595 +7.78934672e-05j, 1.67512732+7.81571827e-05j,
#        1.66922847+7.86028340e-05j, 1.66094525+7.92401466e-05j,
#        1.65025312+8.00839409e-05j, 1.63712124+8.11557006e-05j,
#        1.6215135 +8.24863265e-05j, 1.60339058+8.41212350e-05j,
#        1.58271457+8.61311110e-05j, 1.5774205 +1.66068730e-04j,
#        1.57388942+1.66498915e-04j, 1.56799588+1.67223410e-04j,
#        1.55972723+1.68258132e-04j, 1.5594584 +8.86366882e-05j,
#        1.54906903+1.69617736e-04j, 1.53601168+1.71243999e-04j,
#        1.53362692+9.19569893e-05j, 1.52054265+1.73463904e-04j,
#        1.5053405 +9.64080926e-05j, 1.50269423+1.76086361e-04j])

# %%
mmi_body_waveguide.fraction_te
# Out:
# array([9.99991904e-01, 9.99967183e-01, 9.99924497e-01, 9.99861445e-01,
#        9.99774272e-01, 9.99657368e-01, 9.99502382e-01, 9.99296461e-01,
#        9.99013009e-01, 2.38565216e-04, 9.55099424e-04, 2.13831793e-03,
#        3.73633926e-03, 9.98594348e-01, 5.78997522e-03, 9.32192912e-03,
#        9.96954269e-01, 1.09103635e-02, 9.97247761e-01, 1.38536938e-02])

# %%
mmi_body_waveguide.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)
) #

# %%
mmi_body_waveguide.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
mmi_body_waveguide.plot_field(mode_index=7, # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# #### LO.5.2 Length calculation (𝐿𝜋)
#
# With this information, we could calculate our first guess for the 𝐿𝜋 length of the MMI coupler:

# %%
d_n_eff = mmi_body_waveguide.n_eff[0].real -  mmi_body_waveguide.n_eff[1].real

L_pi = 0.5*lambda_c/(d_n_eff)

print (L_pi)
# Out:
# 219.41119794414357

# %% [markdown]
# ## LO.6. 2x2 Multimode Interference Coupler
#
# ### LO.6.1 Propagation Simulation

# %% [markdown]
# For the multimode interference (MMI) couplers we must rely on the design tables shown on the theoretical session:
#
# <img src="mmi.png" alt="Design tables for MMI couplers" width="600">
#
# Here, you will use some functions provided by us (check **0. Imports** for more details) to simulate the propagation in a 2x2 directional coupler. Please read all the comments in the following code carefully and **make changes only to the lines marked with the #Student tag**

# %%
# Simulation flow for MMI Couplers
# Define your geometrical parameters here
mmi_Width = 6.6 # Student. Body width

m = MMI_EME() # Here you instantiate a MMI to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_width = mmi_Width
m.MMI_num_modes = 20 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 

# 1) Compute de MMI body modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/alexia/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  69.0359860725696  µm
# /home/alexia/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change neither the MMI width 
# nor input/output waveguide widths
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN =  2 # STUDENT
m.n_OUT = 2 # STUDENT

# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (1/2)*L_pi # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/690 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9604
# Total OUT power: 0.9075
# Excess loss [dB] =  0.4217
# ------------------------
# Power over OUTs:  ['0.4675', '0.4399']
# Ratio over OUTs ['0.5152', '0.4848']

# %% [markdown]
# ### LO.6.2. 2x2 Multimode Interference Coupler - Optimization

# %%
dy = 0.027
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.dL_MMI = -0.68  # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/677 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment -0.6800
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9593
# Total OUT power: 0.9083
# Excess loss [dB] =  0.4179
# ------------------------
# Power over OUTs:  ['0.4583', '0.4499']
# Ratio over OUTs ['0.5046', '0.4954']

# %% [markdown]
# ### LO.6.3 2x2 Multimode Interference Coupler – Optimization (II)

# %%
# Design flow for MMI

m = MMI_EME()
m.MMI_width = 6.6   # MMI width
m.wg_width_dw = 0.8 # STUDENT

# 1) Compute de MMI modes
m.find_all_modes()

# 2) Get the L_pi
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/alexia/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  69.03598607256824  µm
# /home/alexia/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN = 2 # STUDENT
m.n_OUT = 2 # STUDENT

dy = 0.015
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (1/2)*L_pi  # STUDENT
m.dL_MMI = 0.3 # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/696 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment 0.3000
# IO wg width 1.0000
# IO wg width increment 0.8000
# ------------------------
# Total power IN coupled 0.9960
# Total OUT power: 0.9788
# Excess loss [dB] =  0.0929
# ------------------------
# Power over OUTs:  ['0.4903', '0.4885']
# Ratio over OUTs ['0.5009', '0.4991']

# %% [markdown]
# ## LO.7. 1x4 Multimode Interference Coupler
#
# Repeat the design procedure explained for the 2x2 Coupler to design a 1x4 MMI Coupler. Consider:
# - Select a suitable MMI body width, taking into account that you now must allocate 4 waveguides at the output.
# - Minimize the losses and output imbalance for the MMI coupler.

# %%
# Simulation flow for MMI Couplers
# Define your geometrical parameters here
mmi_Width = 12# Student. Body width

m = MMI_EME() # Here you instantiate a MMI to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_width = mmi_Width
m.wg_width_dw = 1.1# STUDENT
m.MMI_num_modes = 20 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 

# 1) Compute de MMI body modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN = 1 # STUDENT
m.n_OUT = 4 # STUDENT

dy = -1
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = np.array([0.0]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-3/6,-1/6,1/6,3/6]) + np.array([1.3,0.5,-0.5,-1.3])  # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (3/4/m.n_OUT)*L_pi  # STUDENT
m.dL_MMI = -1# STUDENT

# Run propagation
m.propagation()
# Out:
# /home/alexia/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  219.13931544099964  µm
# /home/alexia/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/12 [00:00<?, ?it/s]
#   0%|          | 0/802 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 41.0886
# MMI length increment -1.0000
# IO wg width 1.0000
# IO wg width increment 1.1000
# ------------------------
# Total power IN coupled 0.9953
# Total OUT power: 0.9880
# Excess loss [dB] =  0.0526
# ------------------------
# Power over OUTs:  ['0.2417', '0.2524', '0.2524', '0.2416']
# Ratio over OUTs ['0.2446', '0.2554', '0.2555', '0.2445']

# %% [markdown]
# ## Extra - Exercises

# %% [markdown]
# ### E1. Directional coupler gap dependence

# %%
#gap_to_simulate = 600 * nm # STUDENT. You can manually change the gap
                            # or you can sweep the parameter using a Python for loop. 
gap_to_simulate = np.arange(0.2,2.6,0.2)
wavelength = 1.55

L_pi_TE = []
L_pi_TM = []

for g in gap_to_simulate:
    deep_dcoupler_cs = gt.modes.WaveguideCoupler(
        wavelength=wavelength, # Wavelength to simulate - Must be a vector
        core_width=(1.0, 1.0), # Waveguide width
        gap=float(g),
        slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
        core_material='sin', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        core_thickness=300 * nm, # Waveguide height 
        num_modes=4, # Number of modes to find
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
        max_grid_scaling=1.5, # Parameters of the grid
        grid_resolution=20 # Parameters of the grid
    )
    dcoupler_neff = deep_dcoupler_cs.n_eff
    
    # TE Modes: Modes 0 & 1
    L_pi_TE.append(0.5*wavelength/(dcoupler_neff[0].real-dcoupler_neff[1].real))
    L_pi_TM.append(0.5*wavelength/(dcoupler_neff[2].real-dcoupler_neff[3].real))

print(L_pi_TE,L_pi_TM)
# STUDENT. Plot goes here
plt.plot(gap_to_simulate, L_pi_TE, label="TE")
plt.plot(gap_to_simulate, L_pi_TM, label="TM")
plt.xlabel("Gap (um)")
plt.ylabel("Lpi")
plt.legend()
plt.show()
# Out:
# 2026-05-02 10:07:54.774 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_19fc40f5ad5a09a8.npz.
# 2026-05-02 10:07:54.785 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_266d67620f0948f9.npz.
# 2026-05-02 10:07:54.788 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fa4c4babd472f540.npz.
# 2026-05-02 10:07:54.793 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f8167db7728a9ebb.npz.
# 2026-05-02 10:07:54.798 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b0f701e58db4a1bf.npz.
# 2026-05-02 10:07:54.802 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_de78bc7bac7ad149.npz.
# 2026-05-02 10:07:54.806 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_69d8430ee5b848c9.npz.
# 2026-05-02 10:07:54.810 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ce577367a47a40cf.npz.
# 2026-05-02 10:07:54.815 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_51919864b2bb47b4.npz.
# 2026-05-02 10:07:54.818 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8e0bd02e52bb6fea.npz.
# 2026-05-02 10:07:54.823 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbd4017b74156e86.npz.
# 2026-05-02 10:07:54.827 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_186b33d829047bed.npz.
# [np.float64(17.68931576265763), np.float64(32.68739325054406), np.float64(58.77155394684144), np.float64(103.11225694961104), np.float64(183.51013066501568), np.float64(320.5436101543248), np.float64(556.7837858494945), np.float64(963.2019697104794), np.float64(878.4228629053757), np.float64(2855.0259109610734), np.float64(4898.714064493818), np.float64(8380.027052813628)] [np.float64(16.71944102460683), np.float64(25.445579290989816), np.float64(38.42630859439877), np.float64(56.51294352784123), np.float64(85.34871817447126), np.float64(125.67039483686207), np.float64(183.82067989165247), np.float64(267.4288678156511), np.float64(344.2790217666101), np.float64(558.7294612316036), np.float64(803.35875026468), np.float64(1151.9340582385746)]

# %%
print(dcoupler_neff)
print(deep_dcoupler_cs.fraction_te)
# Out:
# [1.58342163+0.00011195j 1.58332915+0.00011176j 1.51760639+0.00018153j
#  1.5169336 +0.00018108j]
# [0.99281543 0.99281003 0.01127504 0.01144463]

# %%
gap_to_simulate = np.arange(0.2,2.6,0.2)
wavelength = 1.55

L_pi_TE = []
L_pi_TM = []

for g in gap_to_simulate:
    shallow_dcoupler_cs = gt.modes.WaveguideCoupler(
        wavelength=wavelength, # Wavelength to simulate - Must be a vector
        core_width=(1.0, 1.0), # Waveguide width
        gap=float(g),
        slab_thickness = 150 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
        core_material='sin', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        core_thickness=300 * nm, # Waveguide height 
        num_modes=5, # Number of modes to find
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
        max_grid_scaling=1.5, # Parameters of the grid
        grid_resolution=20 # Parameters of the grid
    )
    dcoupler_neff = shallow_dcoupler_cs.n_eff
    
    # TE Modes: Modes 0 & 1
    L_pi_TE.append(0.5*wavelength/(dcoupler_neff[0].real-dcoupler_neff[1].real))
    L_pi_TM.append(0.5*wavelength/(dcoupler_neff[2].real-dcoupler_neff[4].real))

print(L_pi_TE,L_pi_TM)
# STUDENT. Plot goes here
plt.plot(gap_to_simulate, L_pi_TE, label="TE")
plt.plot(gap_to_simulate, L_pi_TM, label="TM")
plt.xlabel("Gap (um)")
plt.ylabel("Lpi")
plt.legend()
plt.show()
# Out:
# 2026-05-02 10:07:54.965 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b7e41e390984216d.npz.
# 2026-05-02 10:07:54.970 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d756dff4f5b09319.npz.
# 2026-05-02 10:07:54.975 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1c97aadcfff61591.npz.
# 2026-05-02 10:07:54.980 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cb0d5d890abbd68b.npz.
# 2026-05-02 10:07:54.985 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9e9855bfd484b4ef.npz.
# 2026-05-02 10:07:54.989 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_54d5da922b4ec96d.npz.
# 2026-05-02 10:07:54.993 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7abfdcaf9380bea9.npz.
# 2026-05-02 10:07:54.996 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8dd956065b9be03c.npz.
# 2026-05-02 10:07:55.000 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8a6855a5a548a222.npz.
# 2026-05-02 10:07:55.004 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bfc5001039f26e5f.npz.
# 2026-05-02 10:07:55.009 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_60ad39471eda45f0.npz.
# 2026-05-02 10:07:55.013 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1adb96126bff44d4.npz.
# [np.float64(17.71068783997823), np.float64(26.451043760292592), np.float64(39.25252888638957), np.float64(57.948066878620914), np.float64(85.76271990311038), np.float64(126.35514622751057), np.float64(185.86720761649744), np.float64(273.08145381436765), np.float64(397.6997732645101), np.float64(588.228299061918), np.float64(862.7920861819465), np.float64(1265.2310700901871)] [np.float64(26.104369769567473), np.float64(33.26005762263959), np.float64(41.060585583767086), np.float64(50.211261350589666), np.float64(58.18844912074273), np.float64(73.09259361017986), np.float64(89.01102192303976), np.float64(105.23279840323875), np.float64(127.19514862038268), np.float64(137.03440347727897), np.float64(152.2544829409891), np.float64(166.89068277797483)]

# %%
print(shallow_dcoupler_cs.fraction_te)
print(dcoupler_neff)
# Out:
# [0.99607419 0.99602478 0.42512384 0.06705656 0.44385506]
# [1.60715471+0.00010496j 1.60654218+0.00010424j 1.5315381 +0.00016488j
#  1.53153548+0.00017812j 1.52689434+0.00016902j]

# %% [markdown]
# ### E2. Directional coupler wavelength dependence

# %%
wavelength = np.arange(1.5,1.7,0.005) # STUDENT code goes here

L_pi_TE_list = []
L_pi_TM_list = []
for l in wavelength:
    deep_dcoupler_cs = gt.modes.WaveguideCoupler(
        wavelength=l,
        core_width=(1.0, 1.0),
        gap=600 * nm,
        slab_thickness=0 * nm,
        core_material='sin',
        clad_material='sio2',
        core_thickness=300 * nm,
        num_modes=4,
        cache_path='.cache/',
    )

    deep_neff = deep_dcoupler_cs.n_eff

    L_pi_TE = 0.5 * l / (deep_neff[0].real - deep_neff[1].real)
    L_pi_TM = 0.5 * l / (deep_neff[2].real - deep_neff[3].real)

    L_pi_TE_list.append(L_pi_TE)
    L_pi_TM_list.append(L_pi_TM)

plt.figure(figsize=(10, 5))

plt.plot(wavelength, L_pi_TE_list, label='TE')
plt.plot(wavelength, L_pi_TM_list, label='TM')

plt.xlabel("Wavelength (um)")
plt.ylabel("L_pi")
plt.grid()
plt.legend()

plt.show()
# Out:
# 2026-05-02 10:07:55.154 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_13c27ad65d7417a2.npz.
# 2026-05-02 10:07:55.159 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cd3d38e8acc426f2.npz.
# 2026-05-02 10:07:55.165 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6f67058a4d22287f.npz.
# 2026-05-02 10:07:55.171 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_54d9db4ebcd4ad77.npz.
# 2026-05-02 10:07:55.175 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7838bca3b61ac4a6.npz.
# 2026-05-02 10:07:55.178 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8d95e94f8d1df754.npz.
# 2026-05-02 10:07:55.182 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a259590da52e54c0.npz.
# 2026-05-02 10:07:55.186 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a03a40ad2732e8f6.npz.
# 2026-05-02 10:07:55.190 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d481086152e17df5.npz.
# 2026-05-02 10:07:55.194 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6cb0a36818b37a95.npz.
# 2026-05-02 10:07:55.198 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4aaafafb8ac71185.npz.
# 2026-05-02 10:07:55.203 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_88bc7e2611a02564.npz.
# 2026-05-02 10:07:55.206 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e135afa73db91e53.npz.
# 2026-05-02 10:07:55.210 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_53455de806c4754e.npz.
# 2026-05-02 10:07:55.213 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d9663e5f0826b76c.npz.
# 2026-05-02 10:07:55.218 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_956c40fb7c95e77b.npz.
# 2026-05-02 10:07:55.224 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f953d8d824f7a62b.npz.
# 2026-05-02 10:07:55.228 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a650b927839ff9e4.npz.
# 2026-05-02 10:07:55.231 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_da70f5967b803de0.npz.
# 2026-05-02 10:07:55.235 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9d0ef84089534589.npz.
# 2026-05-02 10:07:55.239 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5c57b7d6ab514e60.npz.
# 2026-05-02 10:07:55.242 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ece515c87898b951.npz.
# 2026-05-02 10:07:55.246 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_13e4fdf0f8241b00.npz.
# 2026-05-02 10:07:55.250 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4f069fccbb2c3bb6.npz.
# 2026-05-02 10:07:55.253 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1db2f940b4ead7d9.npz.
# 2026-05-02 10:07:55.257 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8f0348c328487634.npz.
# 2026-05-02 10:07:55.261 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d618385a29972c3a.npz.
# 2026-05-02 10:07:55.264 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6af31b882abf8e97.npz.
# 2026-05-02 10:07:55.268 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_249591518b9d740c.npz.
# 2026-05-02 10:07:55.271 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_12869bfe1d24cd51.npz.
# 2026-05-02 10:07:55.274 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_635d32e1d407c6cd.npz.
# 2026-05-02 10:07:55.277 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6bc963085832c00a.npz.
# 2026-05-02 10:07:55.281 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_11e0c7dbc82d3398.npz.
# 2026-05-02 10:07:55.284 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bd3ddb566206001b.npz.
# 2026-05-02 10:07:55.288 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3d1fac21ccae687a.npz.
# 2026-05-02 10:07:55.290 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d0d3a705e98484e7.npz.
# 2026-05-02 10:07:55.293 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2c8a4f4f275e3918.npz.
# 2026-05-02 10:07:55.296 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c71b5a1f714071dc.npz.
# 2026-05-02 10:07:55.299 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4c5f511fe1103902.npz.
# 2026-05-02 10:07:55.303 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6d8ea96cf36df089.npz.

# %%
print(deep_dcoupler_cs.fraction_te)
print(deep_dcoupler_cs.fraction_tm)
# Out:
# [0.99263104 0.99238321 0.0082929  0.01158006]
# [0.00736896 0.00761679 0.9917071  0.98841994]

# %%
wavelength = np.arange(1.5,1.75,0.05) # STUDENT code goes here
neff_list = []
L_pi_TE_list = []
L_pi_TM_list = []
for l in wavelength:
    shallow_dcoupler_cs = gt.modes.WaveguideCoupler(
        wavelength=l,
        core_width=(1.0, 1.0),
        gap=600 * nm,
        slab_thickness=150 * nm,
        core_material='sin',
        clad_material='sio2',
        core_thickness=300 * nm,
        num_modes=10,
        cache_path='.cache/',
    )

    shallow_neff = shallow_dcoupler_cs.n_eff
    neff_list.append(shallow_neff.real)

    L_pi_TE = 0.5 * l / (shallow_neff[0].real - shallow_neff[1].real)
    L_pi_TM = 0.5 * l / (shallow_neff[2].real - shallow_neff[5].real)

    L_pi_TE_list.append(L_pi_TE)
    L_pi_TM_list.append(L_pi_TM)

plt.figure(figsize=(10, 5))

plt.plot(wavelength, L_pi_TE_list, label='TE')
plt.plot(wavelength, L_pi_TM_list, label='TM')

plt.xlabel("Wavelength (um)")
plt.ylabel("L_pi")
plt.grid()
plt.legend()

plt.show()
# Out:
# 2026-05-02 10:22:17.303 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_142bb74a91699128.npz.
# 2026-05-02 10:22:17.311 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_58bfd83907742ec3.npz.
# 2026-05-02 10:22:17.315 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_12f7ef660afbfba5.npz.
# 2026-05-02 10:22:17.322 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_62e608a92997ed3f.npz.
# 2026-05-02 10:22:17.328 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5330f957976bd4c2.npz.

# %%
print(shallow_dcoupler_cs.fraction_te)
print(shallow_dcoupler_cs.fraction_tm)
print(neff_list)
# Out:
# [0.99649477 0.99624212 0.00836278 0.99026275 0.99347372 0.01936171
#  0.98497893 0.00589352 0.00839945 0.03322222]
# [0.00350523 0.00375788 0.99163722 0.00973725 0.00652628 0.98063829
#  0.01502107 0.99410648 0.99160055 0.96677778]
# [array([1.63095048, 1.61329429, 1.54733729, 1.54095925, 1.53353879,
#        1.52635006, 1.49576888, 1.4571629 , 1.45206986, 1.43881727]), array([1.62038979, 1.60069416, 1.54036073, 1.53285435, 1.52573194,
#        1.51786485, 1.48377621, 1.4519627 , 1.44033698, 1.43676224]), array([1.62018446, 1.59847644, 1.53582545, 1.53504503, 1.52883936,
#        1.51086391, 1.48310303, 1.4475276 , 1.43937706, 1.43583666]), array([1.60578727, 1.58206155, 1.52862137, 1.52362577, 1.51650343,
#        1.50305681, 1.46657147, 1.44315949, 1.43778875, 1.42101238]), array([1.59883508, 1.57318481, 1.52343576, 1.51935945, 1.51195716,
#        1.49650212, 1.45839849, 1.43948023, 1.43726177, 1.41881983])]

# %% [markdown]
# ### E3. MMI coupler wavelength dependence

# %%
mmi_body_w = 6.6 
lambda_c = np.arange(1.5,1.75,0.05) # STUDENT code goes here.

L_pi_TE = []
L_pi_TM = []

for l in lambda_c:
    mmi = gt.modes.Waveguide(
        core_width=mmi_body_w,
        core_thickness=300 * nm,
        slab_thickness=0 * nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=l,
        num_modes=15,
        cache_path='.cache/',
    )

    neff = mmi.n_eff

    # TE (modos 0 y 1)
    dneff_TE = neff[0].real - neff[1].real
    Lpi_TE = 0.5 * l / dneff_TE

    # TM (modos siguientes → depende del orden)
    dneff_TM = neff[9].real - neff[10].real
    Lpi_TM = 0.5 * l / dneff_TM

    L_pi_TE.append(Lpi_TE)
    L_pi_TM.append(Lpi_TM)
    
# STUDENT plot here. 
plt.figure(figsize=(10,5))

plt.plot(lambda_c, L_pi_TE, label="TE")
plt.plot(lambda_c, L_pi_TM, label="TM")

plt.xlabel("Wavelength (um)")
plt.ylabel("L_pi")
plt.grid()
plt.legend()

plt.show()
# Out:
# 2026-05-02 10:07:55.756 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d4ac58ffc32c847d.npz.
# 2026-05-02 10:07:55.761 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_af209a64c974a895.npz.
# 2026-05-02 10:07:55.768 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8cd0be16378bc5c6.npz.
# 2026-05-02 10:07:55.773 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_aef479075a8e904c.npz.
# 2026-05-02 10:07:55.777 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_106febdc32c2e23c.npz.

# %%
print(mmi.fraction_te)
print(mmi.fraction_tm)
# Out:
# [9.99932685e-01 9.99718196e-01 9.99313853e-01 9.98626589e-01
#  7.89767609e-04 9.96737154e-01 3.91589020e-03 6.45858132e-03
#  9.95298403e-01 1.03589939e-02 1.35813464e-02 9.87901905e-01
#  1.57057791e-03 1.85040861e-02 9.96596892e-01]
# [6.73145236e-05 2.81804111e-04 6.86146629e-04 1.37341104e-03
#  9.99210232e-01 3.26284605e-03 9.96084110e-01 9.93541419e-01
#  4.70159662e-03 9.89641006e-01 9.86418654e-01 1.20980946e-02
#  9.98429422e-01 9.81495914e-01 3.40310753e-03]

# %%
mmi_body_w = 6.6 
lambda_c = np.arange(1.5,1.75,0.05) # STUDENT code goes here.

L_pi_TE = []
L_pi_TM = []

for l in lambda_c:
    mmi_shallow = gt.modes.Waveguide(
        core_width=mmi_body_w,
        core_thickness=300 * nm,
        slab_thickness=150 * nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=l,
        num_modes=15,
        cache_path='.cache/',
    )

    neff = mmi_shallow.n_eff

    # TE (modos 0 y 1)
    dneff_TE = neff[0].real - neff[1].real
    Lpi_TE = 0.5 * l / dneff_TE

    # TM (modos siguientes → depende del orden)
    dneff_TM = neff[5].real - neff[6].real
    Lpi_TM = 0.5 * l / dneff_TM

    L_pi_TE.append(Lpi_TE)
    L_pi_TM.append(Lpi_TM)
# Out:
# 2026-05-02 10:07:55.977 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c8e27698cdbda8f1.npz.
# 2026-05-02 10:07:55.985 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_69c9ddf192467e20.npz.
# 2026-05-02 10:07:55.990 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6fc0041648ef7f67.npz.
# 2026-05-02 10:07:55.995 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a4efe94697310380.npz.
# 2026-05-02 10:07:56.000 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5572aab6f7bc7b2a.npz.

# %%
print(mmi_shallow.fraction_te)
print(mmi_shallow.fraction_tm)
# Out:
# [0.9999355  0.99973033 0.99933788 0.9985819  0.99458576 0.00103447
#  0.00708032 0.91882528 0.06040208 0.99968954 0.01031144 0.99555067
#  0.01253377 0.99256164 0.01380912]
# [6.44975220e-05 2.69667306e-04 6.62116282e-04 1.41809615e-03
#  5.41424381e-03 9.98965530e-01 9.92919675e-01 8.11747167e-02
#  9.39597919e-01 3.10458862e-04 9.89688559e-01 4.44932734e-03
#  9.87466226e-01 7.43835533e-03 9.86190879e-01]

# %%
# STUDENT plot here. 
plt.figure(figsize=(10,5))

plt.plot(lambda_c, L_pi_TE, label="TE")
plt.plot(lambda_c, L_pi_TM, label="TM")

plt.xlabel("Wavelength (um)")
plt.ylabel("L_pi")
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# ### E4. MMI coupler body width dependence

# %%
lambda_c = 1.55

mmi_body_w = np.arange(5,11,1)# STUDENT. You can manually change the body width
                 # or you can sweep the parameter using a Python for loop. 

L_pi_TE = []
L_pi_TM = []

for w in mmi_body_w:
    mmi_body_waveguide = gt.modes.Waveguide(
        # Geometrical Parameters
        core_width=w, # MMI Body width
        core_thickness=300 * nm, # MMI Body height 
        slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
        # Materials
        core_material='sin', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        # Modesolver Parameters
        wavelength=lambda_c, # Wavelength to simulate
        num_modes=15, # Targeted number of modes to find - Higher than before! It's a multimode section
        max_grid_scaling=1.5, # Parameters of the grid
        grid_resolution=20, # Parameters of the grid
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
    )

    dneff_TE= mmi_body_waveguide.n_eff[0].real -  mmi_body_waveguide.n_eff[1].real

    Lpi_TE= 0.5 * l / dneff_TE # STUDENT code goes here
    L_pi_TE.append(Lpi_TE)
    
    dneff_TM= mmi_body_waveguide.n_eff[7].real -  mmi_body_waveguide.n_eff[8].real

    Lpi_TM= 0.5 * l / dneff_TM # STUDENT code goes here
    L_pi_TM.append(Lpi_TM)

# STUDENT plot here.
# Out:
# 2026-05-02 10:07:57.249 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_750afcc7e2a92dbc.npz.
# 2026-05-02 10:07:57.255 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7551f8975b22e6de.npz.
# 2026-05-02 10:07:57.260 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b60b2e67cbca1740.npz.
# 2026-05-02 10:07:57.265 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d08a505e5bfefbcb.npz.
# 2026-05-02 10:07:57.273 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_09f64d33f8d29b19.npz.
# 2026-05-02 10:07:57.277 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0715b5214f4328e7.npz.

# %%
print(mmi_body_waveguide.fraction_te)
print(mmi_body_waveguide.fraction_tm)
# Out:
# [9.99985055e-01 9.99939128e-01 9.99858777e-01 9.99737670e-01
#  9.99565477e-01 9.99325762e-01 9.98991193e-01 3.44653034e-04
#  1.34777005e-03 9.98466978e-01 3.04612144e-03 5.27844942e-03
#  9.97779134e-01 8.02533408e-03 1.12446529e-02]
# [1.49451453e-05 6.08724496e-05 1.41222638e-04 2.62329756e-04
#  4.34522809e-04 6.74237931e-04 1.00880724e-03 9.99655347e-01
#  9.98652230e-01 1.53302178e-03 9.96953879e-01 9.94721551e-01
#  2.22086638e-03 9.91974666e-01 9.88755347e-01]

# %%
plt.figure(figsize=(10,5))

plt.plot(mmi_body_w , L_pi_TE, label="TE")
plt.plot(mmi_body_w , L_pi_TM, label="TM")

plt.xlabel("Width (um)")
plt.ylabel("L_pi")
plt.grid()
plt.legend()

plt.show()

# %%
lambda_c = 1.55

mmi_body_w = np.arange(5,10.25,0.25)# STUDENT. You can manually change the body width
                 # or you can sweep the parameter using a Python for loop. 

L_pi_TE = []
L_pi_TM = []

for w in mmi_body_w:
    mmi_body_waveguide = gt.modes.Waveguide(
        # Geometrical Parameters
        core_width=w, # MMI Body width
        core_thickness=300 * nm, # MMI Body height 
        slab_thickness=150 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
        # Materials
        core_material='sin', #  Material of the waveguide
        clad_material='sio2', # Surrounding material
        # Modesolver Parameters
        wavelength=lambda_c, # Wavelength to simulate
        num_modes=15, # Targeted number of modes to find - Higher than before! It's a multimode section
        max_grid_scaling=1.5, # Parameters of the grid
        grid_resolution=20, # Parameters of the grid
        cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
        precision='double',
    )

    dneff_TE= mmi_body_waveguide.n_eff[0].real -  mmi_body_waveguide.n_eff[1].real

    Lpi_TE= 0.5 * l / dneff_TE # STUDENT code goes here
    L_pi_TE.append(Lpi_TE)
    
    dneff_TM= mmi_body_waveguide.n_eff[9].real -  mmi_body_waveguide.n_eff[10].real

    Lpi_TM= 0.5 * l / dneff_TM # STUDENT code goes here
    L_pi_TM.append(Lpi_TM)
# Out:
# 2026-05-02 10:07:57.503 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_49e4659e7cd44e16.npz.
# 2026-05-02 10:07:57.509 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5a85e2a95b32ab0d.npz.
# 2026-05-02 10:07:57.514 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_66f5f615be96f5a1.npz.
# 2026-05-02 10:07:57.518 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_272658903f5dee19.npz.
# 2026-05-02 10:07:57.524 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8be1094f2e34de0e.npz.
# 2026-05-02 10:07:57.528 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ebe7cb6301405a60.npz.
# 2026-05-02 10:07:57.532 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0d38a9666a5a6c2b.npz.
# 2026-05-02 10:07:57.536 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9f917487ee1f428e.npz.
# 2026-05-02 10:07:57.542 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_38632d1eb53ddcb7.npz.
# 2026-05-02 10:07:57.550 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_53d8dda64585e4d7.npz.
# 2026-05-02 10:07:57.554 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_26f5ced0e9153e0c.npz.
# 2026-05-02 10:07:57.559 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_513c6e5926a02d93.npz.
# 2026-05-02 10:07:57.566 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0dd9662150fddf76.npz.
# 2026-05-02 10:07:57.571 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c9c57922bdc7fcb2.npz.
# 2026-05-02 10:07:57.576 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b232d6bb6b978265.npz.
# 2026-05-02 10:07:57.582 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_fc86334d49be113e.npz.
# 2026-05-02 10:07:57.587 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_804027c876514011.npz.
# 2026-05-02 10:07:57.592 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d10c313d885b1b26.npz.
# 2026-05-02 10:07:57.598 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4e080f8573a04258.npz.
# 2026-05-02 10:07:57.603 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5e2c36e9ae668236.npz.
# 2026-05-02 10:07:57.608 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_17e36e7035c1827e.npz.

# %%
print(mmi_body_waveguide.fraction_te)
print(mmi_body_waveguide.fraction_tm)
# Out:
# [0.99998392 0.99993431 0.99984663 0.99971144 0.99950902 0.99918925
#  0.99853128 0.00229442 0.99212128 0.00214098 0.00830712 0.02924745
#  0.97493823 0.01302182 0.99080466]
# [1.60818146e-05 6.56923745e-05 1.53367178e-04 2.88564750e-04
#  4.90976793e-04 8.10745162e-04 1.46872111e-03 9.97705579e-01
#  7.87871956e-03 9.97859022e-01 9.91692880e-01 9.70752553e-01
#  2.50617663e-02 9.86978184e-01 9.19534343e-03]

# %%
plt.figure(figsize=(10,5))

plt.plot(mmi_body_w , L_pi_TE, label="TE")
plt.plot(mmi_body_w , L_pi_TM, label="TM")

plt.xlabel("Width (um)")
plt.ylabel("L_pi")
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# # Grading
# - LO1 - 0.5 Point
# - LO2 - 1 Point
# - LO3 - 1 Point
# - LO4 - 1 Point
# - LO5 - 0.5 Point
# - LO6 - 1 Point
# - LO7 - 2 Points
# - E1-E4 - Up to 3 Points
